# %%
from jinja2 import Environment, FileSystemLoader

# %%
# Assuming your LaTeX template is saved in a directory named 'templates' under the file 'resume_template.tex'
env = Environment(loader=FileSystemLoader('templates'))
template = env.get_template('template.html')

# %%
template
# Out:
# <Template 'template.html'>

# %%
import json
data = json.loads(open('parsed.json').read())

# %%
output = template.render(data=data)
print(output)
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#     <link
#       href="https://fonts.googleapis.com/css?family=Lato:400,300,700"
#       rel="stylesheet"
#       type="text/css"
#     />
#     <style>
#       * {
#         margin: 0;
#         padding: 0;
#         box-sizing: border-box;
#       }
#       html {
#         height: 100%;
#       }
#
#       body {
#         min-height: 100%;
#         background: #eee;
#         font-family: "Lato", sans-serif;
#         font-weight: 400;
#         color: #222;
#         font-size: 14px;
#         line-height: 26px;
#         padding-bottom: 50px;
#       }
#
#       .container {
#         max-width: 700px;
#         background: #fff;
#         margin: 0px auto 0px;
#         box-shadow: 1px 1px 2px #dad7d7;
#         border-radius: 3px;
#         padding: 40px;
#         margin-top: 50px;
#       }
#
#       .header {
#         margin-bottom: 30px;
#
#         .full-name {
#           font-size: 40px;
#           text-transform: uppercase;
# ...

# %%
from IPython.display import display, Latex
display(Latex(output))
# Out:
# \section*{Work Experience}
#
# \begin{itemize}
#
#     \item \textbf{Company}: Dunamu Inc.
#     \item \textbf{Title}: DEVOPS ENGINEER
#     \item \textbf{Period}: Sep. 2023  - Present
#     \item \textbf{Description}: DevOps Engineer at fintech & blockchain company Dunamu which is known for operating Upbit, the largest cryptocurrency exchange in Korea.
#
#
#     \item \textbf{Company}: Danggeun Pay Inc. (KarrotPay)
#     \item \textbf{Title}: FOUNDING MEMBER & SITE RELIABILITY ENGINEER & INFRASTRUCTURE TEAM LEAD
#     \item \textbf{Period}: Mar. 2021  - Jun. 2023
#     \item \textbf{Description}: Led growth at infrastructure departments in two fintech companies as lead engineer and founding member.
#
#     \item \textbf{Impacts}:
#     \begin{itemize}
#
#         \item Designed and provisioned the entire infrastructure on the AWS cloud to meet security compliance and acquire a business license for financial services in Korea.
#
# ...

# %%
with open('resume.html', 'w') as f:
    f.write(output)

# %%
import subprocess

subprocess.run(['pdflatex', 'resume.tex'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 import subprocess
# ----> 3 subprocess.run(['pdflatex', 'resume.tex'])
#
# File ~/anaconda3/envs/agent311/lib/python3.11/subprocess.py:546, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     543     kwargs['stdout'] = PIPE
#     544     kwargs['stderr'] = PIPE
# --> 546 with Popen(*popenargs, **kwargs) as process:
#     547     try:
#     548         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File ~/anaconda3/envs/agent311/lib/python3.11/subprocess.py:1022, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
# ...

# %%
import pdflatex

# %%
pdfl = pdflatex.PDFLaTeX.from_jinja2_template(template, data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pdfl = pdflatex.PDFLaTeX.from_jinja2_template(template, data)
#
# AttributeError: type object 'PDFLaTeX' has no attribute 'from_jinja2_template'
